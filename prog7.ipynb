# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
plt.imshow(image)

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
image_mat= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_mat)

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
image_mat= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_mat)

plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
image_mat= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

ht,wd,c=image.shape
midx=wd//2
midy=ht//2

tl=image_mat[:midy,:midx]
tr=image_mat[:midy,midx:]
bl=image_mat[midy:,:midx]
br=image_mat[midy:,midx:]

plt.imshow(tl)


plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
image_mat= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

ht,wd,c=image.shape
midx=wd//2
midy=ht//2

tl=image_mat[:midy,:midx]
tr=image_mat[:midy,midx:]
bl=image_mat[midy:,:midx]
br=image_mat[midy:,midx:]

fig,axs=plt.subplots(2,2)

axs[0,0].imshow(tl)
axs[0,0].axis('off')
axs[0,0].set_title("Top Left")

axs[0,1].imshow(tr)
axs[0,1].axis('off')
axs[0,1].set_title("Top Right")

axs[1,0].imshow(bl)
axs[1,0].axis('off')
axs[1,0].set_title("Bottom Left")

axs[1,1].imshow(br)
axs[1,1].axis('off')
axs[1,1].set_title("Bottom Right")


plt.axis("off")
plt.show()

# %%
# Using for LOOP

import cv2
import matplotlib.pyplot as plt
image = cv2.imread('fru.jpeg')
image_mat= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

ht,wd,c=image.shape
midx=wd//2
midy=ht//2

tl=image_mat[:midy,:midx]
tr=image_mat[:midy,midx:]
bl=image_mat[midy:,:midx]
br=image_mat[midy:,midx:]

fig,axs=plt.subplots(2,2)

l_title=["Top Left","Top Right","Bottom Left","Bottom Right"]
l_var=[tl,tr,bl,br]
k=0

for i in range(2):
    for j in range(2):
        axs[i,j].imshow(l_var[k])
        axs[i,j].axis("off")
        axs[i,j].set_title(l_title[k])
        k=k+1
        
plt.show()

# %% [markdown]
# pip install opencv-python

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\harsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\harsh\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
